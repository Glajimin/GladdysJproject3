# %% [markdown]
# **Gladdys Jiminian**
#
# **Data Sience**
#
# **Dr. Melamed**
#
# **11/17/2025**

# %% [markdown]
# # Project Part 3: Data Cleaning and Exploration
#
# ## 1. Introduction
#
# In this project I am looking at how blocking a gene called *Smad3* changes gene expression patterns related to fat accumulation and metabolism in mice. I am using an RNA expression data set from mouse liver tissue to connect specific genes to hepatic steatosis (fatty liver) and high-fat diet. My goal is to explore the data set and understand its structure. Additionaly, I want to make some basic summaries and visualizations that relate back to the hypotheses from the paper.

# %% [markdown]
# ## Section 3: Visualizations and data
#
# **Figure 1**
#
# <img src="figure1.png" width="350">
#
#
# **img src="figure1.png" width="350"**
# -I used this line of code to project my image in my markdown cell
# -This can be done for both images but you must change the file name "" to the correct file that is stored in the same folder as your jupyter notebook.
#
# Figure 1:
#
# i. In this experiment scientists measured the activity of specific anti-inflammatory genes in the fat tissue of mice to see how a high-fat diet and the absence of the Smad3 gene would affect them. The groups tested were wild-type mice which have the Smad3 gene active and Smad3 knockout mice that don’t have this gene active. Each mouse was fed either a regular diet or a high-fat diet. The figure shows gene expression for the genes Il10, Chi3l3, Arg1, Mrc2, Mgl2, and Mgl1. The Y-axis represents how much the expression increased or decreased compared to the control group, and the X-axis lists the genes. The bars are colored by whatever control the mouse was and whether it was wild type or not. Wild type, regular diet is gray; Wild type, high-fat diet is black; Knockout, regular diet is light blue; and Knockout, high-fat diet is red. Each bar represents the average gene expression change for that group, with small vertical lines showing the variation between samples.
#
# ii. The authors included this figure to show how blocking the Smad3 gene changes immune and inflammatory responses in fat cells. They wanted to know if the Smad3 knockout cells would make liver tissue less inflamed under a high-fat diet and looked at genes that show up when an immune response is needed. This figure helps demonstrate that the knockout mice express these protective genes more strongly than the wild type mice.
#
# iii. From this figure we can conclude that knockout mice have higher expression of anti-inflammatory and M2 macrophage marker genes. When fed a high-fat diet, genes like Mgl1, Mgl2, Mrc2, and Arg1 are much more active in the knockout, high-fat diet group compared to Wild type, high-fat diet mice, while Chi3l3 and Il10 show smaller differences. This means that the absence of Smad3 gives rise to immune genes that seem more protective.
#
# **Figure 2**
#
#
# <img src="figure2.png" width="350">
#
#
# Figure 2:
#
# i. This figure was generated by measuring oxygen consumption rate over time in two groups of cells. The control is the black line, and this one has the Smad3 gene expressed. The red line called ShSmad3 has the Smad3 gene silenced. The X-axis shows time in minutes, and the Y-axis shows oxygen consumption rate, which reflects how much cells are using oxygen. Each point on the graph represents the average oxygen consumption rate measured at that time point for each cell in the designated control.
#
# ii. This experiment helps show how the Smad3 gene affects energy metabolism in cells. Measuring oxygen consumption rate allows scientists to see how much energy the cells produce and how efficiently they burn oxygen. The red line represents cells where Smad3 was blocked, while the black line shows normal control cells. By comparing both lines, researchers can see whether the loss of Smad3 changes how much energy the cells make.
#
# iii. The authors included this figure to show that blocking Smad3 increases energy production. It supports their overall hypothesis that Smad3 limits metabolic activity and that removing or silencing it allows cells to become more energetically and metabolically active. When norepinephrine is added, the ShSmad3 cells show a strong increase in oxygen consumption rate, while control cells have less response. This demonstrates that cells lacking Smad3 have higher oxygen consumption and stronger activation of metabolism, which connects directly to the idea that Smad3 suppresses fat burning and mitochondrial function.
#
# **Additonal Figures**: An additional figure I would make is a comparison between mitochondrial activity and how much fat the cells store when the Smad3 gene is blocked. The figure would have two parts. The first part would be a bar graph showing the average mitochondrial activity in the control cells that have the gene expressed, versus the Smad3 knockdown cells that have the gene silenced. The X-axis would have the two groups: control and ShSmad3 which is the silenced gene. The Y-axis would show the mitochondrial activity. I would expect the ShSmad3 bar to be higher since blocking Smad3 makes the cells burn more energy. The second part would be an image showing the cells under a microscope stained with red dye that marks fat droplets. The control cells would have more red spots, showing fat stored, while the ShSmad3 cells would have fewer and smaller spots. This figure would help connect the energy measurements to the physical change in the cells, showing that when Smad3 is turned off, the cells become more metabolically active and store less fat.
#
#
#
# ### 2.2 Summary of what I improved from my previous submission
#
# From my earlier project version, one big issue I had was confusing observations and features. Before, I wasn’t very clear about what counted as a mouse compared to what counted as a gene measurement. In this version I made sure to state that each row in the data set is a single gene (ENSMUSG IDs) and each column after the "Gene" column is one mouse sample (GSM IDs), with expression values as the features for each gene. I also rewrote my figure descriptions to be more organized, first explaining what is on each axis and then what each group or line means, and finally what conclusion the authors want to show with the figure. Overall, I tried to make my explanations less confusing and more directly connected to the research questions about Smad3, high-fat diet, and hepatic steatosis.

# %% [markdown]
# ## 3. Part 3: Data cleaning and exploration
#
# ### 3.1 Load and clean data
#
# The RNA expression data I am using comes from the NCBI Gene Expression Omnibus (GEO) with accession GSE28598. To get the same file I am using, someone can:
#
# -Go to the GEO website and search for GSE28598.
#
# - For much simpler acces go to the reserch paper where the link to dowload the data can be found (Scroll all the way to the bottom where it says *associated data*
#   https://pubmed.ncbi.nlm.nih.gov/21723505/
#
# -Download the expression data file
#
# -Open it in Excel or another spreadsheet program and save it as a CSV file called GSE28598.csv
#
# -Put GSE28598.csv in the same folder as this Jupyter notebook so pd.read_csv can find it.
#
# In my notebook, I read in the CSV like this:

# %%
import pandas as pd #Imports data files through Pandas

#First i have to create a variable name for data and then assing this variable name to the data using this code...
data = pd.read_csv("GSE28598.csv")

# I use .head() bc it looks at the first few rows
data.head()

# %% [markdown]
# The code above imports **pandas** and calls **pd.read_csv("GSE28598.csv")** to load the table into a DataFrame called **data**. Because the CSV is in the same directory as my notebook and already has a header row with column names, I do not need any extra options. The **data.head()** line shows the first few rows so I can check that the columns look correct. In this data set, the first column is called **"Gene"** (with ENSMUSG IDs), and the other columns are GSM identifiers for each mouse sample, with numeric expression values.
#
# Next, I check the basic info and whether there are any missing values that I would need to clean:

# %%
# Check for basic information about the data frame
data.info()

# Check for missing values in each column
data.isna().sum()

# %% [markdown]
# **data.info()** tells me how many rows and columns there are, the column names, and the data types (for example, **object** for gene IDs and **float64** for the expression values). Then **data.isna().sum()** counts how many missing values (**NaN**) are in each column. In my case, the output shows that there are 0 missing values in all columns, so I do not need to drop or fill any rows. Because the file already has clean numeric values and proper labels, it is suitable for further analysis without extra cleaning steps.
#
# To double-check the shape of the table, I can also run:

# %%
data.shape

# %% [markdown]
# This shows that the data frame has 17,918 rows and 13 columns. One column is the "Gene" ID, and the other 12 columns are expression measurements for 12 mouse samples.

# %% [markdown]
# ### 3.2 Describe data numerically
#
# Now I describe the shape more carefully:
#
# #### Shape: observations and features
#
# The shape output from **data.shape** is:
#
# - 17,918 rows
# - 13 columns
#
# In this experiment:
#
# - Each **row** is one gene (an ENSMUSG ID), so the number of **observations** is 17,918 genes.
# - Each **column after "Gene"** is one mouse sample (GSM ID), so there are 12 numeric **features** that give the expression level of that gene in each mouse.
#
# So I can say:
#
# This data frame has 17,918 observations (genes) and 12 numeric features (expression values for each mouse), plus one column that stores the gene name.
#
# #### Two features to investigate
#
# I pick two of the mouse expression columns:
#
# - **GSM707747** – expression level of each gene in one mouse
# - **GSM707748** – expression level of each gene in a second mouse
#
# Both are numeric columns with 17,918 values.
#
# Before running **describe()**, I expect:
#
# - The count for both features to be 17,918 no missing values.
# - The mean to be a positive number in the low single values, because most genes will have low expression and a smaller group of genes will be highly expressed.
# - The min to be a little below zero, since the values look like log scaled expression and log values tend to be negative at the start.
# - The max to be much higher than the median, because a few genes are very highly expressed, which makes the distribution right-skewed.
#
# Now I actually run **describe()** on both features:

# %%
data[["GSM707747", "GSM707748"]].describe()

# %% [markdown]
# -This line of code selects just two columns from my data set, **GSM707747 and GSM707748**, and runs the describe() function on them. The double brackets are used because I am choosing more than one column at the same time. The describe() function gives me a summary of the main statistics for each feature, like the count, mean, standard deviation, minimum value, median, and maximum value. This helps me understand the overall distribution of expression levels for these two mouse samples and check if they match what I expected based on the dataset.

# %% [markdown]
# For this data, the main results are:
#
# -count = 17,918 for both
#
# -mean = 3.42
#
# -std = 8.11
#
# -min = −0.57
#
# -50% (median) = 0.97
#
# -max = 182.46
#
# The count matches exactly what I expected, every gene has a value in both columns. The mean around 3–4 is also consistent with a lot of low or moderate expression and a few highly expressed genes pulling the average up. The max being *182* shows there are some outlier genes with very high expression. One interesting thing is that the two columns, GSM707747 and GSM707748, have the same summary statistics, which already hints that they have very similar expression profiles for all the genes, even though they are not exactly identical gene by gene.

# %% [markdown]
# ### 3.3 Visualizations
#
# Now I make two visualizations, one for each feature I picked in 3.2. I use **seaborn** and **matplotlib**.
#
# #### Visualization 1: Histogram of expression for GSM707747
#
# **Feature 1.1**
#
# For the first feature, **GSM707747**, I want to make a histogram of its expression values.
#
# A histogram is best because:
#
# - It is univirate and shows how the values are distributed.
#
# - It lets me see if most genes have low expression, high or if expression is spread out evenly.
#
# - It connects directly to the describe() summary by showing the shape of the distribution.
#
# **Code to make the histogram**

# %%
# I import seaborn because I'm using it to make the histogram plot
import seaborn as sns

# I import matplotlib to actually display the plot and add labels/titles
import matplotlib.pyplot as plt

# I create a new figure so the histogram appears clean and not on top of other plots
plt.figure()

# This makes the actual histogram of the expression values for the GSM707747 column
# I set bins=50 just to make the shape of the distribution smoother
sns.histplot(data=expr, x="GSM707747", bins=50)

# This adds a label to the x-axis so I know what the numbers represent
plt.xlabel("Expression level (GSM707747)")

# This adds a label to the y-axis showing I'm counting how many genes fall in each bin
plt.ylabel("Number of genes")

# This gives the whole graph a title so it's clear what I'm looking at
plt.title("Distribution of gene expression for mouse GSM707747")

# This shows the plot on the screen
plt.show()

# %% [markdown]
# The code above uses **sns.histplot** with the data frame **data**, using **"GSM707747"** as the x-axis and 50 bins to get a smoother histogram that includes a lotof the data. The labels explain that each bar shows how many genes fall into a certain range of expression values for that mouse. **plt.show()** displays the plot.
#
# When I look at the histogram, most genes have expression values clustered between about 0 and maybe 5, with a long tail stretching out to around 180. This matches the **describe()** output:
#
# - The **median** (~0.97) is much lower than the **max**, which I can see as a huge difference between the main bulk of the bars and a few bars further to the right.
# - The distribution is *right-skewed*, many genes are low or moderately expressed, and a small number have very high expression (the tail).
#
# This fits with the biological idea that only a subset of genes are strongly turned on in this condition, while many others stay at low levels. It also relates back to Figure 1 from the paper, where only certain anti-inflammatory genes, like **Mgl1**, **Mgl2**, **Mrc2**, and **Arg1**, show large changes in expression under different diets and Smad3 status. Those strongly expressed or strongly changed genes likely live in the high-expression tail of the distribution.
#
# #### Visualization 2: Scatter plot comparing GSM707747 and GSM707748
#
# **Figure 2.2**
#
# For the second feature, **GSM707748**, I want to compare it directly to **GSM707747** using a **scatter plot**, with:
#
# - X-axis = expression in GSM707747
# - Y-axis = expression in GSM707748
#
# This is the best plot becuase:
#
# - It is a bivariate plot that shows how similar or different the two mouse samples are gene by gene.
#
# - If the points lie close to a diagonal line, it means the expression levels in the two samples are very similar for each gene.
#
#
# - It helps check whether these columns represent truly different mice or whether we are looking at highly similar patterns.
#
#  **Code to make the scatterplot**

# %%
# I make a new figure so this scatter plot doesn't overlap with any other plots
plt.figure()

# This creates the scatter plot comparing the two mouse columns
# Each point is one gene, and it shows how similar the two expression values are
sns.scatterplot(data=data, x="GSM707747", y="GSM707748")

# Label the x-axis so it's clear which mouse sample the values come from
plt.xlabel("Expression level (GSM707747)")

# label the y-axis for the second mouse sample
plt.ylabel("Expression level (GSM707748)")

# This adds a title so the graph is easier to understand
plt.title("Gene expression: GSM707747 vs GSM707748")

# Finally, this actually shows the scatter plot
plt.show()

# %% [markdown]
# Here I again use *sns.scatterplot* with **data** as the data frame, and I map **"GSM707747"** to the x-axis and **"GSM707748"** to the y-axis. Each point in the plot is one gene, and its position shows how highly that gene is expressed in mouse GSM707747 compared to mouse GSM707748.
#
# When I look at the scatter plot, the points fall very close to the diagonal line **y = x**, meaning that for most genes, the expression value in GSM707747 is very similar to the value in **GSM707748**. This is consistent with the **describe()** table, where the two columns had the same mean, standard deviation, median, and other summary statistics. Even though the columns are not exactly identical gene by gene, they clearly have almost the same distribution and a very strong positive relationship.
#
# Even though this single file does not separate the mice clearly by diet or genotype, the overall pattern is still useful. The fact that these GSM (gene) columns behave so similarly suggests we might be working with a normalized expression pattern that reflects the typical response under the conditions used in the paper. The earlier figures (like Figure 2, showing higher oxygen consumption when Smad3 is silenced) illustrate functional differences between groups. My scatter plot shows that within this summarized expression table, the-sample differences are small, which means I would need additional phenotype information (like which GSM is high-fat diet vs. normal diet, or wild type vs. knockout) to directly reproduce the group-wise comparisons from the paper.
